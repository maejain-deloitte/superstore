# %%
import pandas as pd

# %%
df = pd.read_csv("superstore.csv")
display(df)
# Out:
#       Unnamed: 0  level_0  index     Id  Year_Birth   Education  \
# 0              0        0      0   1826        1970  Graduation
# 1              1        1      1      1        1961  Graduation
# 2              2        2      2  10476        1958  Graduation
# 3              3        3      3   1386        1967  Graduation
# 4              4        4      4   5371        1989  Graduation
# ...          ...      ...    ...    ...         ...         ...
# 2211        2211     2211   2235  10142        1976         PhD
# 2212        2212     2212   2236   5263        1977    2n Cycle
# 2213        2213     2213   2237     22        1976  Graduation
# 2214        2214     2214   2238    528        1978  Graduation
# 2215        2215     2215   2239   4070        1969         PhD
#
#      Marital_Status   Income  Kidhome  Teenhome  ... MntFishProducts  \
# 0          Divorced  84835.0        0         0  ...             111
# ...
